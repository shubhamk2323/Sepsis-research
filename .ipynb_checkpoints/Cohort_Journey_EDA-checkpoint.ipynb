# %% [markdown]
# # Cohort Patient Journey — Sepsis vs Normal (Aggregated Means)
#
# Comparing the **average trends** of a cohort of ICU patients who developed sepsis vs those who did not.
#
# By averaging across multiple patients (e.g. 50 sepsis, 50 normal), we cancel out individual noise and reveal the true underlying clinical patterns leading up to sepsis onset.

# %% [markdown]
# ## Step 1: Load Cohort & Align Timelines

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import warnings
warnings.filterwarnings('ignore')

# Load enough data to get a solid cohort quickly
df_full = pd.read_csv('combined_sepsis_data.csv', low_memory=False, nrows=500000)

# Identify patients
pat_summary = df_full.groupby('Patient_ID')['SepsisLabel'].max().reset_index()

# Select a cohort: 50 Sepsis patients, 50 Normal patients
sepsis_ids = pat_summary[pat_summary['SepsisLabel'] == 1]['Patient_ID'].head(50).values
normal_ids = pat_summary[pat_summary['SepsisLabel'] == 0]['Patient_ID'].head(50).values

print(f"Selected {len(sepsis_ids)} Sepsis patients and {len(normal_ids)} Normal patients.")

pt_sep = df_full[df_full['Patient_ID'].isin(sepsis_ids)].copy()
pt_nor = df_full[df_full['Patient_ID'].isin(normal_ids)].copy()

# Add a relative hour column
# For Sepsis: 0 = onset, negative = before onset
def align_sepsis(grp):
    labels = grp['SepsisLabel'].values
    onset_pos = np.where(labels == 1)[0]
    if len(onset_pos) == 0:
        return grp
    onset_idx = onset_pos[0]
    grp['rel_hour'] = np.arange(len(grp)) - onset_idx
    return grp

pt_sep = pt_sep.groupby('Patient_ID', group_keys=False).apply(align_sepsis)

# For Normal: Just use the ICU hour (0 = admission)
# To compare visually, we'll shift the normal patients' time axis so we see them
# spanning the same timeline range as the sepsis patients. 
# Typical sepsis onset is often 10-24 hours in, so shifting by 12 aligns them nicely on the graph.
pt_nor['rel_hour'] = pt_nor.groupby('Patient_ID').cumcount() - 12

print("Data aligned successfully.")

# %% [markdown]
# ## Plot 1: Average Vital Signs Hour-by-Hour
#
# Solid line = Mean value. Shaded area = 95% Confidence Interval.
# You can clearly see trends like Heart Rate creeping up hours before onset.

# %%
vitals = ['HR', 'Resp', 'MAP', 'Temp', 'O2Sat']
vital_labels = {
    'HR':    'Average Heart Rate (bpm)',
    'Resp':  'Average Respiratory Rate (breaths/min)',
    'MAP':   'Average MAP (mmHg)',
    'Temp':  'Average Body Temperature (C)',
    'O2Sat': 'Average Oxygen Saturation (%)',
}

for v in vitals:
    pt_sep[v] = pd.to_numeric(pt_sep[v], errors='coerce')
    pt_nor[v] = pd.to_numeric(pt_nor[v], errors='coerce')

# Calculate Means and Standard Errors
# Sepsis window: -24 to +6
sep_agg = pt_sep[pt_sep['rel_hour'].between(-24, 6)].groupby('rel_hour')[vitals].agg(['mean', 'sem'])
nor_agg = pt_nor[pt_nor['rel_hour'].between(-24, 12)].groupby('rel_hour')[vitals].agg(['mean', 'sem'])

fig, axes = plt.subplots(len(vitals), 1, figsize=(14, 16))
fig.patch.set_facecolor('#0F1117')
fig.suptitle('Cohort Vital Signs: 50 Sepsis vs 50 Normal Patients\n(Sepsis onset aligned at Hour 0)',
             color='white', fontsize=14, fontweight='bold', y=1.01)

for ax, v in zip(axes, vitals):
    ax.set_facecolor('#0F1117')
    
    # Normal Line
    x_nor = nor_agg.index
    y_nor = nor_agg[(v, 'mean')]
    e_nor = nor_agg[(v, 'sem')] * 1.96  # 95% Confidence Interval
    
    ax.plot(x_nor, y_nor, color='#4ADE80', lw=2.5, label='Normal Cohort Mean', zorder=3)
    ax.fill_between(x_nor, y_nor - e_nor, y_nor + e_nor, color='#4ADE80', alpha=0.15, zorder=2)
    
    # Sepsis Line
    x_sep = sep_agg.index
    y_sep = sep_agg[(v, 'mean')]
    e_sep = sep_agg[(v, 'sem')] * 1.96
    
    ax.plot(x_sep, y_sep, color='#FF6B6B', lw=2.5, label='Sepsis Cohort Mean', zorder=3)
    ax.fill_between(x_sep, y_sep - e_sep, y_sep + e_sep, color='#FF6B6B', alpha=0.15, zorder=2)

    # Sepsis Onset Line
    ax.axvline(0, color='#FF4444', lw=2, ls='--', alpha=0.9, label='Sepsis Onset (hr 0)', zorder=4)

    ax.set_ylabel(vital_labels[v], color='#CCCCCC', fontsize=10)
    ax.tick_params(colors='#AAAAAA')
    for spine in ax.spines.values(): spine.set_visible(False)
    ax.yaxis.grid(True, color='#2A2A3A', lw=0.8)
    ax.set_axisbelow(True)
    ax.legend(facecolor='#1A1A2E', edgecolor='none', labelcolor='white', fontsize=9, loc='upper left')

axes[-1].set_xlabel('Hours Relative to Sepsis Onset', color='#AAAAAA', fontsize=11)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Plot 2: Average Lab Values Over Time
#
# Dots indicate hours where we have sufficient lab measurements across the cohort.

# %%
labs = ['Lactate', 'Creatinine', 'BUN', 'WBC', 'pH', 'Hgb']
lab_labels = {
    'Lactate':    'Avg Lactate (mmol/L)',
    'Creatinine': 'Avg Creatinine (mg/dL)',
    'BUN':        'Avg BUN (mg/dL)',
    'WBC':        'Avg WBC (K/uL)',
    'pH':         'Avg Blood pH',
    'Hgb':        'Avg Hemoglobin (g/dL)',
}

thresholds = {
    'Lactate':    2.0, 'Creatinine': 1.2, 'BUN': 20, 
    'WBC':        12,  'pH': 7.35, 'Hgb': 12,
}

for l in labs:
    pt_sep[l] = pd.to_numeric(pt_sep[l], errors='coerce')
    pt_nor[l] = pd.to_numeric(pt_nor[l], errors='coerce')

sep_agg_lab = pt_sep[pt_sep['rel_hour'].between(-24, 6)].groupby('rel_hour')[labs].agg(['mean', 'sem'])
nor_agg_lab = pt_nor[pt_nor['rel_hour'].between(-24, 12)].groupby('rel_hour')[labs].agg(['mean', 'sem'])

fig, axes = plt.subplots(2, 3, figsize=(16, 10))
fig.patch.set_facecolor('#0F1117')
fig.suptitle('Average Lab Values: 50 Sepsis vs 50 Normal Patients',
             color='white', fontsize=13, fontweight='bold')

for ax, lab in zip(axes.flatten(), labs):
    ax.set_facecolor('#0F1117')
    
    # We dropna to avoid plotting gaps if no patient had a lab at that hour
    y_nor = nor_agg_lab[(lab, 'mean')].dropna()
    x_nor = y_nor.index
    ax.plot(x_nor, y_nor, 'o-', color='#4ADE80', lw=2, ms=6, label='Normal Mean', zorder=3)
    
    y_sep = sep_agg_lab[(lab, 'mean')].dropna()
    x_sep = y_sep.index
    ax.plot(x_sep, y_sep, 'o-', color='#FF6B6B', lw=2, ms=6, label='Sepsis Mean', zorder=3)

    if lab in thresholds:
        thresh = thresholds[lab]
        ax.axhline(thresh, color='#FFD700', lw=1.5, ls='--', alpha=0.8, label=f'Clinical threshold ({thresh})')

    ax.axvline(0, color='#FF4444', lw=1.5, ls='--', alpha=0.7, label='Sepsis onset (hr 0)')

    ax.set_title(lab, color='white', fontweight='bold')
    ax.set_ylabel(lab_labels[lab], color='#CCCCCC', fontsize=9)
    ax.set_xlabel('Hours Relative to Sepsis Onset', color='#AAAAAA', fontsize=9)
    ax.tick_params(colors='#AAAAAA')
    for spine in ax.spines.values(): spine.set_visible(False)
    ax.yaxis.grid(True, color='#2A2A3A', lw=0.8)
    ax.set_axisbelow(True)
    ax.legend(facecolor='#1A1A2E', edgecolor='none', labelcolor='white', fontsize=7, loc='best')

plt.tight_layout()
plt.show()
